# %% [markdown]
# # 微塑料去除大创中期评分

# %% [markdown]
# ## 1.研究论文
# EI会议论文——4分<P>
# EI国内一般会议墙报——1分

# %% [markdown]
# ## 2.专利
# 实用新型：一种复合生物炭与牡蛎壳的水产养殖微塑料去除装置（ZL 2022 2 0590397.4）——2.5分<p>
#   软著：

# %%
from IPython.display import Image 
Image(filename="G:\python\图片\微信截图_20230808054227.png",width=200)

# %%
from IPython.display import Image 
Image(filename="G:\python\图片\微信截图_20230808054302.png",width=200)

# %%
from IPython.display import Image 
Image(filename="G:\python\图片\微信截图_20230808054323.png",width=200)

# %% [markdown]
# ## 3.学科竞赛获奖（A类）
# 大挑省二——18分

# %% [markdown]
# ## 4.作品——按abc类还是按主办单位级别？
# 参展：比赛布展算吗

# %% [markdown]
# ### 4.1国家级主办单位
# 应用型c国二——18分<p>
# 可再生c类复赛保国二——18分<p>
# 创青春碳中和c类省三——5分<p>

# %% [markdown]
# ### 4.2参展：比赛布展算吗？
# 可再生、小挑、节能减排

# %% [markdown]
# ## 5. 咨询调研报告
# 例子：<P>
# 市级部门采纳：
# 海洋与渔业局

# %%
from IPython.display import Image 
Image(filename="G:\python\微信图片_20230807141152.png",width=200)

# %% [markdown]
# ## 6.其他成果——有限制分数吗？
# bp、实物——0.5分
# 设计、调查、综述——0.2分
